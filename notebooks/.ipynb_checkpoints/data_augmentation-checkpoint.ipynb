# %%
import cv2     # opencv3
import glob    # to get lists of matching files
import numpy as np

from PIL import Image
from io import BytesIO

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
def get_label_paths(label):
    # all file paths, as a list
    file_paths = glob.glob("../data/imgs/*.jpg") 

    # get a list of matching file paths
    matching_paths = [path for path in file_paths if "_{:}.jpg".format(label) in path]
    
    return matching_paths

# %%
paths = get_label_paths(83)

# %%
paths[0]
# Out:
# '../data/imgs/91252_83.jpg'

# %%
img = cv2.imread("../data/imgs/91252_83.jpg")

# resized = cv2.resize(img, (299, 299), interpolation=cv2.INTER_AREA)

fig, ax = plt.subplots()
ax.imshow(img)

# %%
# img.shape   # (412, 550, 3)
mirror_img = resized[:, ::-1, :]

# %%
fig, ax = plt.subplots()
ax.imshow(mirror_img)

# %%
pil_image = Image.fromarray(mirror_img)

# %%
pil_image.size
# Out:
# (299, 299)

# %%
pil_image.save("../data/stage1_imgs/test.jpg", format='JPEG', quality=90)

# %%
temp = "../data/stage1_imgs/test.jpg".split("/")

# %%
temp[-1] = "flip_" + temp[-1]
temp = "/".join(temp)
temp
# Out:
# '../data/stage1_imgs/flip_test.jpg'
